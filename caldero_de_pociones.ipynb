# %%
pociones = [
{"nombre":"Invisibilidad","ingredientes":[3,5,2]},
{"nombre":"Vuelo","ingredientes":[10,8,9]},
{"nombre":"Curación","ingredientes":[6,4,5]},
{"nombre":"Explosión","ingredientes":[20,25,18]}
]
resultado = [
p["nombre"]
for p in pociones
if max(p["ingredientes"]) > 30
]
print(resultado)
# Out:
# []

# %% [markdown]
# ¿Qué criatura ha poseído a Merlinius? Ni idea
# ● ¿Tiene errores sintácticos? No
# ● ¿Por qué el hechizo falla? porque comprueva los ingredientes de manera individual no los suma por el max del if
# ● Corrige el conjuro.

# %%
pociones = [
{"nombre":"Invisibilidad","ingredientes":[3,5,2]},
{"nombre":"Vuelo","ingredientes":[10,8,9]},
{"nombre":"Curación","ingredientes":[6,4,5]},
{"nombre":"Explosión","ingredientes":[20,25,18]}
]
resultado = [
p["nombre"]
for p in pociones
    if sum(p["ingredientes"]) > 30
]
print(resultado)
# Out:
# ['Explosión']
