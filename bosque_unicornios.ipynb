# %% [markdown]
# codigo original

# %%
felicidad = [
[10,15,20],
[25,40,35],
[5,8,9]
]
altos = [
fila
for fila in felicidad
for nivel in fila
if nivel>20
]
print(altos)
# Out:
# [25, 40, 35]

# %% [markdown]
# ¿Qué devuelve realmente? la segunda lista 3 veces
# ¿Por qué? se guardava la fila entera no los datos individuales
# Corrígelo.

# %%
felicidad = [
[10,15,20],
[25,40,35],
[5,8,9]
]
altos = [
nivel
for fila in felicidad
for nivel in fila
if nivel>20
]
print(altos)
# Out:
# [25, 40, 35]
