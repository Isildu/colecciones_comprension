# %% [markdown]
# hechizom mal

# %%
dragones = [
{"nombre":"Smaug","oro":[500,800,700]},
{"nombre":"Firulais","oro":[20,15,40]},
{"nombre":"Pepito","oro":[150,180,200]}
]
medias = {
d["nombre"]:max(d["oro"])/len(d["oro"])
for d in dragones
}
print(medias)
# Out:
# {'Smaug': 266.6666666666667, 'Firulais': 13.333333333333334, 'Pepito': 66.66666666666667}

# %% [markdown]
# ● Explica qué está haciendo realmente. Agarra el mayor numero de orro de cada dragon y lo divide entre el numero total de oros que tiene ese dragon
# ● Corrige el conjuro.
# ● ¿Por qué este error es especialmente peligroso? hace solo la media del horo maximo no de todo el oro de cada dragon

# %%
dragones = [
{"nombre":"Smaug","oro":[500,800,700]},
{"nombre":"Firulais","oro":[20,15,40]},
{"nombre":"Pepito","oro":[150,180,200]}
]
medias = {
d["nombre"]:sum(d["oro"])/len(d["oro"])
for d in dragones
}
print(medias)
# Out:
# {'Smaug': 666.6666666666666, 'Firulais': 25.0, 'Pepito': 176.66666666666666}
