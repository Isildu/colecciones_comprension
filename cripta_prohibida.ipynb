# %% [markdown]
# codigo original

# %%
cofres = [
{"esqueleto":"Bob","oro":[10,12,15]},
{"esqueleto":"Jack","oro":[80,90,120]},
{"esqueleto":"Luis","oro":[30,20,25]}
]
ricos = [
s["esqueleto"]
for s in cofres
if sum(s["oro"]/len(s["oro"]))>50
]
print(ricos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 {"esqueleto":"Bob","oro":[10,12,15]},
#       3 {"esqueleto":"Jack","oro":[80,90,120]},
#       4 {"esqueleto":"Luis","oro":[30,20,25]}
#       5 ]
# ----> 6 ricos = [
#       7 s["esqueleto"]
#       8 for s in cofres
#       9 if sum(s["oro"]/len(s["oro"]))>50
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %% [markdown]
# 1. Explica el error. no puede dividir un numero con una lista.
# 2. Corrígelo.
# 3. ¿Quién es realmente rico? Jack

# %%
cofres = [
{"esqueleto":"Bob","oro":[10,12,15]},
{"esqueleto":"Jack","oro":[80,90,120]},
{"esqueleto":"Luis","oro":[30,20,25]}
]
ricos = [
s["esqueleto"] 
for s in cofres
if sum(s["oro"]) / len(s["oro"]) > 50
]
print(ricos)
# Out:
# ['Jack']
