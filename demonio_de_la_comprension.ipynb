# %% [markdown]
# codigo original

# %%
grimorio = [
{"nombre":"Fuego","energia":[8,10,12]},
{"nombre":"Hielo","energia":[3,5,6]},
{"nombre":"Rayo","energia":[15,14,16]},
{"nombre":"Luz","energia":[7,7,8]}
]
hechizos = {
h["nombre"]:sum(h["energia"])
for h in grimorio
if max(h["energia"])>20
}
print(hechizos)
# Out:
# {}

# %% [markdown]
# ● ¿Qué hace realmente el programa? mostrar echizos cuya energia maxima sea superior a 20
# ● ¿Qué pretendía hacer? mostrar echizos cuyo conjunto total de energia sea superior a 20
# ● ¿Qué errores contiene? al final tiene un max en lugar de una suma
# ● Reescríbelo correctamente.

# %%
grimorio = [
{"nombre":"Fuego","energia":[8,10,12]},
{"nombre":"Hielo","energia":[3,5,6]},
{"nombre":"Rayo","energia":[15,14,16]},
{"nombre":"Luz","energia":[7,7,8]}
]
hechizos = {
h["nombre"]:sum(h["energia"])
for h in grimorio
if sum(h["energia"])>20
}
print(hechizos)
# Out:
# {'Fuego': 30, 'Rayo': 45, 'Luz': 22}
